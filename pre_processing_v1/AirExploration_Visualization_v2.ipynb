# %% [markdown]
# ### Import library

# %%
import numpy as np
import pandas as pd
import seaborn ; seaborn.set()
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### load data

# %%
data = pd.read_excel('DataAIQ2.xlsx')
data.head(10)
# Out:
#    year  month  day  hour        No2         No          CO      PM10  \
# 0  2018     11   14     0  34.309217   7.794375  241.904055  4.670333
# 1  2018     11   14     1  36.773427  14.919750  231.640179  5.652583
# 2  2018     11   14     2  28.623000   6.588125  225.559657  4.926417
# 3  2018     11   14     3  30.079687   4.905278  241.517235  6.310917
# 4  2018     11   14     4  29.210657   2.752000  236.343171  6.286500
# 5  2018     11   14     5  31.510367   3.392500  226.993101  6.146417
# 6  2018     11   14     6  37.488140   8.163542  246.550465  4.171583
# 7  2018     11   14     7  54.432893  28.553333  268.164916  3.403667
# 8  2018     11   14     8  59.406903  43.556250  236.147376  1.465583
# 9  2018     11   14     9  58.587067  37.746354  240.236744  2.155167
#
#         PM1     PM2.5         O3   Humidity     Pressure  ParticleCount  \
# 0  0.984500  2.135750  11.750583  80.783333  1012.291667       0.004671
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5569 entries, 0 to 5568
# Data columns (total 15 columns):
# year             5569 non-null int64
# month            5569 non-null int64
# day              5569 non-null int64
# hour             5569 non-null int64
# No2              5569 non-null float64
# No               5569 non-null float64
# CO               5569 non-null float64
# PM10             5569 non-null float64
# PM1              5569 non-null float64
# PM2.5            5569 non-null float64
# O3               5569 non-null float64
# Humidity         5569 non-null float64
# Pressure         5569 non-null float64
# ParticleCount    5569 non-null float64
# VehicleCount     5569 non-null float64
# dtypes: float64(11), int64(4)
# memory usage: 652.7 KB

# %%
X = data.drop('year' , axis = 1)
X2=X.drop('month' , axis = 1)
X3=X2.drop('day' , axis = 1)
X3=X3.drop('hour' , axis = 1)
X3.describe()
# Out:
#                No2           No           CO         PM10          PM1  \
# count  5569.000000  5569.000000  5569.000000  5569.000000  5569.000000
# mean     44.857476    52.468001   264.658894     8.127476     2.464253
# std      14.046065    39.549271    58.964242     8.112021     2.812962
# min      11.867137     2.752000    68.965249     0.477500     0.130000
# 25%      34.246294    26.644422   228.918269     3.889167     0.910563
# 50%      44.474420    42.556190   254.070750     5.842250     1.525833
# 75%      54.143285    66.436175   288.794858     9.175441     2.928706
# max     130.914433   394.411607   837.610954   213.777500    43.175000
#
#              PM2.5           O3     Humidity     Pressure  ParticleCount  \
# count  5569.000000  5569.000000  5569.000000  5569.000000    5569.000000
# mean      4.798233    -0.140006    76.004304  1007.684745       0.019110
# std       5.584422   395.390749     9.811419    13.541626       0.063014
# ...

# %%
data.groupby('year').mean()
# Out:
#           month        day       hour        No2         No          CO  \
# year
# 2018  11.879850  17.362954  11.565707  43.859059  55.851458  276.535458
# 2019   5.320964  15.430608  13.433962  45.024716  51.901254  262.669507
#
#           PM10       PM1     PM2.5          O3   Humidity     Pressure  \
# year
# 2018  9.258125  2.252944  4.972694 -160.862335  82.478215  1007.625041
# 2019  7.938087  2.499648  4.769010   26.781827  74.919890  1007.694746
#
#       ParticleCount  VehicleCount
# year
# 2018       0.007454     97.302879
# 2019       0.021063    139.981551

# %%
data.groupby('year').sum()
# Out:
#       month    day   hour            No2             No            CO  \
# year
# 2018   9492  13873   9241   35043.388026   44625.314789  2.209518e+05
# 2019  25381  73604  64080  214767.897531  247568.980630  1.252934e+06
#
#               PM10           PM1         PM2.5             O3       Humidity  \
# year
# 2018   7397.242165   1800.102403   3973.182124 -128529.005430   65900.094028
# 2019  37864.673549  11923.320671  22748.176480  127749.314018  357367.875906
#
#           Pressure  ParticleCount  VehicleCount
# year
# 2018  8.050924e+05       5.956131       77745.0
# 2019  4.806704e+06     100.468615      667712.0

# %% [markdown]
# ## visulization

# %%
data.hist(figsize=(15,15), layout=(5,5), color = 'green')
plt.show()



#print quartile plot for outlier detection
data.plot(kind='box', subplots=True, figsize=(15,15), layout=(5,5), sharex=False, sharey=False)
plt.show()

# %%
import seaborn ; seaborn.set()
import seaborn as sns
#plot heatmap for corralation
sns.heatmap(data.corr(), cmap='coolwarm', annot=True, fmt=".1f", annot_kws={'size':8})

# %%
sns.jointplot(x='PM1',y='PM10',data=data)

# %%
sns.jointplot(x='No',y='No2',data=data)
