# %% [markdown]
# ### Import library

# %%
import numpy as np
import pandas as pd
import seaborn ; seaborn.set()
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %matplotlib inline

filename_short = '2.5.6'
filename_short = filename_short.replace(".", "_")
print(filename_short)
# Out:
# 2_5_6

# %% [markdown]
# ### load data

# %%
for filename in os.listdir('../2019_new'):
    if filename.endswith('.csv'):
        
        
        size_filename = len(filename)
        filename_short = filename[:size_filename - 4]
        filename_short = filename_short.replace(".", "_")
        
        path_main = '../2019_new/'+filename
        path_avg = '../2019_avg/' + filename_short + '_avg.csv'
        
        print(filename)
        print(filename_short)
        
        print(size_filename)
        
        print(path_main)
        print(path_avg)
        
        
        value = filename_short
        #sensor_id_value = 'sensor_id_AverageSpeed'

        
        #read the orginal dataset
        dataset = pd.read_csv(path_main)

        # datetime for the timestamp on year, month, day, hour
        dataset["datetime"] = pd.to_datetime(dataset["timestamp"])
        dataset["datetime"]

        dataset["year"] = dataset["datetime"].dt.year
        dataset["month"] = dataset["datetime"].dt.month
        dataset["day"] = dataset["datetime"].dt.day
        dataset["hour"] = dataset["datetime"].dt.hour

        # make a mean from the dataset based on hour
        datasethourlymean = dataset.groupby(["year","month","day","hour"]).value.mean()

        # read the mean dataset and saved it in avg folder
        datasethourlymean.to_csv(path_avg, index = True, header = True)
        datasetavg = pd.read_csv(path_avg)

        # rename value header and replace it based on the variable
        datasetavg.rename(columns={'value': value},inplace=True)

        # rename sensor_id header and replace it based on the variable
        #datasetavg.rename(columns={'sensor_id': sensor_id_value},inplace=True)

        # save and read the processed dataset
        datasetavg.to_csv(path_avg,index = False)
        #datasetavg = pd.read_csv(path_avg)
        #datasetavg
# Out:
# NO2.csv
# NO2
# 7
# ../2019_new/NO2.csv
# ../2019_avg/NO2_avg.csv
# O3.csv
# O3
# 6
# ../2019_new/O3.csv
# ../2019_avg/O3_avg.csv
# Wind Direction.csv
# Wind Direction
# 18
# ../2019_new/Wind Direction.csv
# ../2019_avg/Wind Direction_avg.csv
# Particle Count.csv
# Particle Count
# 18
# ../2019_new/Particle Count.csv
# ../2019_avg/Particle Count_avg.csv
# Traffic Flow.csv
# Traffic Flow
# 16
# ../2019_new/Traffic Flow.csv
# ../2019_avg/Traffic Flow_avg.csv
# PM 4.csv
# PM 4
# 8
# ../2019_new/PM 4.csv
# ../2019_avg/PM 4_avg.csv
# Rain Acc.csv
# Rain Acc
# 12
# ../2019_new/Rain Acc.csv
# ../2019_avg/Rain Acc_avg.csv
# PM2.5.csv
# PM2_5
# 9
# ../2019_new/PM2.5.csv
# ../2019_avg/PM2_5_avg.csv
# Congestion.csv
# Congestion
# 14
# ../2019_new/Congestion.csv
# ../2019_avg/Congestion_avg.csv
# Solar Diffuse Radiation.csv
# Solar Diffuse Radiation
# 27
# ../2019_new/Solar Diffuse Radiation.csv
# ../2019_avg/Solar Diffuse Radiation_avg.csv
# Average Speed.csv
# Average Speed
# 17
# ../2019_new/Average Speed.csv
# ../2019_avg/Average Speed_avg.csv
# PM1.csv
# PM1
# 7
# ../2019_new/PM1.csv
# ../2019_avg/PM1_avg.csv
# Wind Speed.csv
# Wind Speed
# 14
# ../2019_new/Wind Speed.csv
# ../2019_avg/Wind Speed_avg.csv
# Rain Duration.csv
# Rain Duration
# 17
# ../2019_new/Rain Duration.csv
# ../2019_avg/Rain Duration_avg.csv
# Pressure.csv
# Pressure
# 12
# ../2019_new/Pressure.csv
# ../2019_avg/Pressure_avg.csv
# Solar Radiation.csv
# Solar Radiation
# 19
# ../2019_new/Solar Radiation.csv
# ../2019_avg/Solar Radiation_avg.csv
# Max Wind Speed.csv
# Max Wind Speed
# 18
# ../2019_new/Max Wind Speed.csv
# ../2019_avg/Max Wind Speed_avg.csv
# NOx.csv
# NOx
# 7
# ../2019_new/NOx.csv
# ../2019_avg/NOx_avg.csv
# CO.csv
# CO
# 6
# ../2019_new/CO.csv
# ../2019_avg/CO_avg.csv
# PM10.csv
# PM10
# 8
# ../2019_new/PM10.csv
# ../2019_avg/PM10_avg.csv
# Brood.csv
# Brood
# 9
# ../2019_new/Brood.csv
# ../2019_avg/Brood_avg.csv
# NO.csv
# NO
# 6
# ../2019_new/NO.csv
# ../2019_avg/NO_avg.csv

# %%
i=0
path_first= '../2019_avg/NO2_avg.csv'
mix = pd.read_csv(path_first)

for filename in os.listdir('../2019_avg'):
    if i<20 and filename != 'NO2_avg.csv' and filename.endswith('.csv'):
        i = i+1
        print(filename)
        path_avg= '../2019_avg/'+filename
        next_file = pd.read_csv(path_avg)
        mix = pd.merge(next_file, mix, how='inner', on=['year','month','hour', 'day'])

    
mix.to_csv('../mix2019/mix2019.csv',index=False)
mix = pd.read_csv('../mix2019/mix2019.csv')
display(mix)
# Out:
# PM1_avg.csv
# CO_avg.csv
# Wind Direction_avg.csv
# PM10_avg.csv
# PM 4_avg.csv
# NOx_avg.csv
# NO_avg.csv
# Brood_avg.csv
# Congestion_avg.csv
# Solar Diffuse Radiation_avg.csv
# Average Speed_avg.csv
# Particle Count_avg.csv
#      year  month  day  hour  Particle Count  Average Speed  \
# 0    2019      1    1     1        3.699637      78.891429
# 1    2019      1    1     2        2.708226      80.000000
# 2    2019      1    1     3        2.476456      79.890000
# 3    2019      1    1     4        1.942571      80.000000
# 4    2019      1    1     5        3.860117      79.527363
# ..    ...    ...  ...   ...             ...            ...
# 262  2019      3    1    19       10.697453      44.320000
# 263  2019      3    1    20       12.961959      48.123333
# 264  2019      3    1    21       16.382342      53.273333
# 265  2019      3    1    22       18.673322      62.380000
# 266  2019      3    1    23       19.176250      70.643333
#
#      Solar Diffuse Radiation  Congestion      Brood         NO        NOx  \
# 0                   1.881455    0.000000  27.631258  79.471396  11.472812
# 1                   1.540601    0.000000  32.117217  76.776609  10.347500
# 2                   1.385936    0.000000  27.013431  76.364023   6.223250
# 3                   1.465212    0.000000  31.472528  72.415781   5.201500
# 4                   2.160352    0.000000  26.583639  75.146877   5.438750
# ..                       ...         ...        ...        ...        ...
# 262                 1.404281    0.026667  30.378860  33.008657  83.168750
# 263                 1.679178    0.036667  29.216118  31.618371  80.848625
# 264                 1.319686    0.006667  30.160126  34.884834  83.113563
# 265                 1.496732    0.000000  29.162394  32.773044  78.528000
# 266                 1.391878    0.000000  29.929880  27.425521  73.289563
#
#           PM 4       PM10  Wind Direction          CO       PM1        NO2
# 0     3.812788   7.859820      234.812252  -12.200916  2.665401  46.909070
# 1     2.915618   6.422894      237.815560   -8.987211  2.248828  47.618677
# 2     2.713444   6.138027      235.593609    9.411359  2.154563  45.269821
# 3     2.238189   5.419912      231.130303    0.825578  2.001630  43.204186
# 4     3.333777   8.172640      189.895256  -32.991823  1.919470  39.950562
# ..         ...        ...             ...         ...       ...        ...
# 262  15.880940  23.617440      225.963977  504.095185  5.132476  26.206978
# 263  20.882855  29.868755      218.597518  720.104759  5.313002  30.215924
# 264  25.566943  35.385952      205.413905  623.561817  5.937034  40.816996
# 265  30.394340  41.352855      215.023913  660.551158  6.741396  41.148551
# 266  31.932222  43.400769      241.603623  388.569492  6.946452  38.767457
#
# [267 rows x 17 columns]
